# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Set the path to the data
data_dir = '/content/drive/My Drive/SRI'
csv_file = '/content/drive/My Drive/SRI/english.csv'

# %%
# Load the CSV file
data = pd.read_csv(csv_file)

data
# Out:
#                    image label
# 0     Img/img001-001.png     0
# 1     Img/img001-002.png     0
# 2     Img/img001-003.png     0
# 3     Img/img001-004.png     0
# 4     Img/img001-005.png     0
# ...                  ...   ...
# 3405  Img/img062-051.png     z
# 3406  Img/img062-052.png     z
# 3407  Img/img062-053.png     z
# 3408  Img/img062-054.png     z
# 3409  Img/img062-055.png     z
#
# [3410 rows x 2 columns]

# %%
# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(data['image'], data['label'], test_size=0.3, random_state=42)

# %%
# Preprocess the data
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_dataframe(
    dataframe=data.loc[X_train.index],
    directory=data_dir,
    x_col="image",
    y_col="label",
    target_size=(400, 300),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 2387 validated image filenames belonging to 62 classes.

# %%
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = val_datagen.flow_from_dataframe(
    dataframe=data.loc[X_val.index],
    directory=data_dir,
    x_col="image",
    y_col="label",
    target_size=(400, 300),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 1023 validated image filenames belonging to 62 classes.

# %%
# Load the pre-trained DenseNet121 model
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(400, 300, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# %%
# Add custom layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
output = Dense(62, activation='softmax')(x)

# %%
model = Model(inputs=base_model.input, outputs=output)

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(train_generator, epochs=20, validation_data=val_generator)
# Out:
# Epoch 1/20
# 75/75 [==============================] - 1506s 20s/step - loss: 3.4746 - accuracy: 0.2158 - val_loss: 2.7161 - val_accuracy: 0.4252
# Epoch 2/20
# 75/75 [==============================] - 49s 658ms/step - loss: 2.2751 - accuracy: 0.5563 - val_loss: 1.9393 - val_accuracy: 0.6598
# Epoch 3/20
# 75/75 [==============================] - 49s 649ms/step - loss: 1.6663 - accuracy: 0.7055 - val_loss: 1.5499 - val_accuracy: 0.7077
# Epoch 4/20
# 75/75 [==============================] - 49s 653ms/step - loss: 1.3322 - accuracy: 0.7675 - val_loss: 1.3392 - val_accuracy: 0.7116
# Epoch 5/20
# 75/75 [==============================] - 49s 650ms/step - loss: 1.1106 - accuracy: 0.7935 - val_loss: 1.1631 - val_accuracy: 0.7595
# Epoch 6/20
# 75/75 [==============================] - 49s 650ms/step - loss: 0.9693 - accuracy: 0.8081 - val_loss: 1.0466 - val_accuracy: 0.7722
# Epoch 7/20
# 75/75 [==============================] - 49s 652ms/step - loss: 0.8631 - accuracy: 0.8287 - val_loss: 0.9946 - val_accuracy: 0.7654
# Epoch 8/20
# 75/75 [==============================] - 48s 644ms/step - loss: 0.7737 - accuracy: 0.8475 - val_loss: 0.9156 - val_accuracy: 0.7840
# Epoch 9/20
# 75/75 [==============================] - 49s 652ms/step - loss: 0.7138 - accuracy: 0.8475 - val_loss: 0.8689 - val_accuracy: 0.7879
# Epoch 10/20
# 75/75 [==============================] - 48s 643ms/step - loss: 0.6617 - accuracy: 0.8601 - val_loss: 0.8517 - val_accuracy: 0.7889
# Epoch 11/20
# 75/75 [==============================] - 49s 657ms/step - loss: 0.6180 - accuracy: 0.8701 - val_loss: 0.7888 - val_accuracy: 0.8055
# Epoch 12/20
# 75/75 [==============================] - 49s 648ms/step - loss: 0.5761 - accuracy: 0.8764 - val_loss: 0.7630 - val_accuracy: 0.8055
# Epoch 13/20
# 75/75 [==============================] - 49s 649ms/step - loss: 0.5452 - accuracy: 0.8831 - val_loss: 0.7315 - val_accuracy: 0.8113
# Epoch 14/20
# 75/75 [==============================] - 49s 651ms/step - loss: 0.5149 - accuracy: 0.8865 - val_loss: 0.7194 - val_accuracy: 0.7967
# Epoch 15/20
# 75/75 [==============================] - 49s 648ms/step - loss: 0.4886 - accuracy: 0.8923 - val_loss: 0.7041 - val_accuracy: 0.8182
# Epoch 16/20
# 75/75 [==============================] - 49s 655ms/step - loss: 0.4606 - accuracy: 0.9007 - val_loss: 0.6917 - val_accuracy: 0.8221
# Epoch 17/20
# 75/75 [==============================] - 49s 656ms/step - loss: 0.4437 - accuracy: 0.9045 - val_loss: 0.6750 - val_accuracy: 0.8162
# Epoch 18/20
# 75/75 [==============================] - 48s 643ms/step - loss: 0.4179 - accuracy: 0.9108 - val_loss: 0.6644 - val_accuracy: 0.8162
# Epoch 19/20
# 75/75 [==============================] - 49s 653ms/step - loss: 0.4037 - accuracy: 0.9049 - val_loss: 0.6593 - val_accuracy: 0.8152
# Epoch 20/20
# 75/75 [==============================] - 48s 647ms/step - loss: 0.3854 - accuracy: 0.9116 - val_loss: 0.6333 - val_accuracy: 0.8270

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_dataframe(
    dataframe=data.loc[X_val.index],
    directory=data_dir,
    x_col="image",
    y_col="label",
    target_size=(400, 300),
    batch_size=32,
    class_mode='categorical'
)

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Found 1023 validated image filenames belonging to 62 classes.
# 32/32 [==============================] - 15s 455ms/step - loss: 0.6333 - accuracy: 0.8270
# Test Accuracy: 0.8270

# %%
import joblib

joblib.dump(model, '/content/drive/My Drive/SRI/DenseNet121_model2.pkl')
# Out:
# ['/content/drive/My Drive/SRI/DenseNet121_model2.pkl']
